# %% [markdown]
# # XGBoost Notebook - Simple Matching
#
# The purpose of this notebook is to use the results from the simple matching scheme and predict the slope of road links.
#
# For run time considerations, the following code is run once and then skipped in place of reading the pickled file:
#
#     probe_data = pd.read_csv(os.path.join(DATA_DIR, "simple_match.csv"))
#     probe_data['dateTime'] = pd.to_datetime(probe_data['dateTime'])
#     probe_data.to_pickle(os.path.join(DATA_DIR, 'converted_simple_match.pickle'))

# %%
# Imports
        
import os
import xgboost as xgb
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %matplotlib inline

from datetime import datetime


# Constants
DATA_DIR = "probe_data_map_matching"

link_headers = ["linkPVID", 
                "refNodeID", 
                "nrefNodeID", 
                "length", 
                "functionalClass", 
                "directionOfTravel", 
                "speedCategory", 
                "fromRefSpeedLimit", 
                "toRefSpeedLimit", 
                "fromRefNumLanes", 
                "toRefNumLanes", 
                "multiDigitized", 
                "urban", 
                "timeZone", 
                "shapeInfo", 
                "curvatureInfo", 
                "slopeInfo"]

# %%
# Read in the Link Data
link_data = pd.read_csv(os.path.join(DATA_DIR, "Partition6467LinkData.csv"), header=None, names=link_headers)
link_data.drop('curvatureInfo', axis=1, inplace=True)

print(link_data.shape)

link_data.head()
# Out:
# (200089, 16)
#     linkPVID  refNodeID  nrefNodeID  length  functionalClass  \
# 0   62007637  162844982   162809070  335.04                5
# 1  567329767  162844982   162981512  134.56                5
# 2   62007648  162877732   162844982   97.01                5
# 3   78670326  162877732   163152693  314.84                5
# 4   51881672  174713859   174587951  110.17                3
#
#   directionOfTravel  speedCategory  fromRefSpeedLimit  toRefSpeedLimit  \
# 0                 B              7                 30               30
# 1                 B              7                  0                0
# 2                 B              7                 30               30
# 3                 B              7                 30               30
# 4                 B              6                 50               50
#
#    fromRefNumLanes  toRefNumLanes multiDigitized urban  timeZone  \
# 0                0              0              F     T       0.0
# 1                0              0              F     T       0.0
# 2                0              0              F     T       0.0
# 3                0              0              F     T       0.0
# 4                2              2              F     T       0.0
#
#                                            shapeInfo                 slopeInfo
# 0        51.4965800/9.3862299/|51.4994700/9.3848799/                       NaN
# 1  51.4965800/9.3862299/|51.4966899/9.3867100/|51...                       NaN
# 2        51.4962899/9.3849100/|51.4965800/9.3862299/                       NaN
# 3        51.4962899/9.3849100/|51.4990000/9.3836099/                       NaN
# 4  53.0643099/8.7903400/45.79|53.0650299/8.791470...  0.00/-0.090|110.17/0.062

# %%
# how many have slope info?
link_data.dropna().shape
# Out:
# (53517, 16)

# %%
# Actually get rid of the missings
link_data.dropna(inplace=True)

# %%
# Read in the (Matched) Probe Data

probe_data = pd.read_csv(os.path.join(DATA_DIR, "simple_match.csv"))
probe_data['dateTime'] = pd.to_datetime(probe_data['dateTime'], format='%m/%d/%Y %I:%M:%S %p')
#probe_data.to_pickle(os.path.join(DATA_DIR, 'converted_simple_match.pickle'))

#probe_data = pd.read_pickle(os.path.join(DATA_DIR, 'converted_simple_match.pickle'))

# %% [markdown]
# ## Quick Analysis of Simple Matching Results
#
# Here we take a quick look to see what kind of coverage we have from the simple matching scheme. Do we match to most of the links? Very few?

# %%
probe_data.shape
# Out:
# (3375745, 12)

# %%
# How many unique linkPVID's are contained in the matched probe data
print("Roughly what do the Groups look like?")
itr = 0
for i in probe_data.groupby('linkPVID').groups:
    if itr <= 5:
        print(i, probe_data.groupby('linkPVID').groups[i])
        itr += 1

print("There are {} Unique linkPVID's represented".format(len(probe_data.groupby('linkPVID').groups)))
# Out:
# Roughly what do the Groups look like?
# 51514446.0 Int64Index([1209248, 1209249, 1209972, 1735597, 2008557, 2157649, 2465899,
#             2465900, 2465901, 2465902, 2676287, 2676289],
#            dtype='int64')
# 51514498.0 Int64Index([735887, 1847541, 2184794], dtype='int64')
# 51514539.0 Int64Index([735883, 2459937, 2459939, 2459940, 2459941], dtype='int64')
# 51514549.0 Int64Index([2010729], dtype='int64')
# 51514619.0 Int64Index([1689192, 2466256], dtype='int64')
# 51514638.0 Int64Index([735879, 735926, 2466252, 2466257], dtype='int64')
# There are 191082 Unique linkPVID's represented

# %% [markdown]
# So, 191082 Unique PVID's are covered. Given that there are roughly 200,000 links in the dataset, this level of coverage is actually quite good.

# %% [markdown]
# ### Join to Link Data

# %%
joined_data = probe_data.join(link_data.set_index('linkPVID'), on='linkPVID', how='inner', lsuffix='l', rsuffix='r')

# %%
joined_data.head()
# Out:
#         sampleID            dateTime  sourceCode   latitude  longitude  \
# 0           3496 2009-06-12 06:12:49          13  51.496868   9.386022
# 185405    288451 2009-08-19 05:51:03          13  51.492852   9.382393
# 185406    288451 2009-08-19 05:51:08          13  51.492875   9.382403
# 185407    288451 2009-08-19 05:51:13          13  51.492911   9.382495
# 202731      3496 2009-06-12 06:12:49          13  51.496868   9.386022
#
#         altitude  speed  heading     linkPVID direction  \
# 0            200     23      339  706849300.0         B
# 185405       200      0      212  706849300.0         B
# 185406       200      2      230  706849300.0         B
# 185407       200      0      214  706849300.0         B
# 202731       200     23      339  706849300.0         B
#
#                         ...                   speedCategory  \
# 0                       ...                               6
# 185405                  ...                               6
# 185406                  ...                               6
# 185407                  ...                               6
# 202731                  ...                               6
#
#         fromRefSpeedLimit  toRefSpeedLimit  fromRefNumLanes  toRefNumLanes  \
# 0                      50               50                1              1
# 185405                 50               50                1              1
# 185406                 50               50                1              1
# 185407                 50               50                1              1
# 202731                 50               50                1              1
#
#         multiDigitized urban  timeZone  \
# 0                    F     T       0.0
# 185405               F     T       0.0
# 185406               F     T       0.0
# 185407               F     T       0.0
# 202731               F     T       0.0
#
#                                                 shapeInfo  \
# 0       51.4940599/9.3834099/202.91|51.4941200/9.38343...
# 185405  51.4940599/9.3834099/202.91|51.4941200/9.38343...
# 185406  51.4940599/9.3834099/202.91|51.4941200/9.38343...
# 185407  51.4940599/9.3834099/202.91|51.4941200/9.38343...
# 202731  51.4940599/9.3834099/202.91|51.4941200/9.38343...
#
#                                    slopeInfo
# 0       0.00/-1.442|6.82/-1.275|15.96/-0.919
# 185405  0.00/-1.442|6.82/-1.275|15.96/-0.919
# 185406  0.00/-1.442|6.82/-1.275|15.96/-0.919
# 185407  0.00/-1.442|6.82/-1.275|15.96/-0.919
# 202731  0.00/-1.442|6.82/-1.275|15.96/-0.919
#
# [5 rows x 27 columns]

# %%
print("And now after the join and NA removal, we have {} rows of data".format(joined_data.shape[0]))
# Out:
# And now after the join and NA removal, we have 1631245 rows of data

# %% [markdown]
# ## Model Setup
#
# Here we want to build an ML Model to predict the slope of a link given some gps probe data. In order to do that we'll use the average slope of the link as the target and (a subset) of the rest of the columns of data as features for the model to predict it.
#
# We opt to use XGBoost for a couple reasons:
#
# First, it is a tree-based model which we think is well-suited to the lat/lon features. While we are doing a _regression_ model, we do not believe that a linear regression is the best tool for it since latitude and longitude, while real-valued, are not truly ordinal features well-suited to linear (OLS) modeling. On the other hand, tree-based (in particular boosted tree-based) models allow us to learn a complex topographical map over these features because of different split points.
#
# Second, it is stable, well-developed and highly parallelizable which is allows us to scale to large datasets. This is appropriate because we have 3.3 million probe points.
#
# Finally, XGBoost is a favorite among Data Scientists and Kaggle Competition winners due to its often first-class performance without requiring as much data, maintenance, or computing resources as neural networks. And, since we are not interested in automatic feature extraction such as one might attempt with Deep Learning, we think that XGBoost is a good fit.

# %% [markdown]
# ## Feature Engineering
#
# However, that doesn't mean that we aren't interested in creating new features. We think that there could be a lot of value in features that take the sequence of probe points (the trajectory) into account. These rollup features are things like distance traveled since last point, change in speed, change in elevation, sliding window estimates of slope, etc.
#
# They are computed below.

# %%
def rolling_diff(df):
    return df[-1] - df[0]

cleaned_joined_data = joined_data.dropna()

cleaned_joined_data['avg_link_slope'] = cleaned_joined_data['slopeInfo'].apply(lambda x: np.mean([float(i.split('/')[1]) for i in x.split('|')]))

gdf = cleaned_joined_data.groupby('sampleID')
cleaned_joined_data['delta_elevation'] = gdf['altitude'].apply(lambda x: x.rolling(2, min_periods=2).apply(rolling_diff)).reset_index(0, drop=True)
cleaned_joined_data['delta_latitude'] = gdf['latitude'].apply(lambda x: x.rolling(2, min_periods=2).apply(rolling_diff)).reset_index(0, drop=True)
cleaned_joined_data['delta_longitude'] = gdf['longitude'].apply(lambda x: x.rolling(2, min_periods=2).apply(rolling_diff)).reset_index(0, drop=True)
cleaned_joined_data['delta_speed'] = gdf['speed'].apply(lambda x: x.rolling(2, min_periods=2).apply(rolling_diff)).reset_index(0, drop=True)
cleaned_joined_data['rolling_slope'] = cleaned_joined_data['delta_elevation'] / np.sqrt(cleaned_joined_data['delta_latitude'] ** 2 + cleaned_joined_data['delta_longitude'] ** 2)
cleaned_joined_data['rolling_acc'] = cleaned_joined_data['delta_speed'] / np.sqrt(cleaned_joined_data['delta_latitude'] ** 2 + cleaned_joined_data['delta_longitude'] ** 2)

cleaned_joined_data = cleaned_joined_data.dropna()

# %%
subset = cleaned_joined_data[[#'sampleID',
                   #'dateTime',
                   'altitude',
                    'latitude', 
                    'longitude',
                   'speed', 
                   #'heading', 
                   'length',
                   #'functionalClass',
                   'fromRefSpeedLimit', 
                   #'toRefSpeedLimit', 
                   'fromRefNumLanes', 
                   #'toRefNumLanes',
                    #'delta_elevation',
                    'delta_speed',
                    'rolling_slope',
                   'avg_link_slope']]

print(subset.shape)
import sklearn
train, test = sklearn.cross_validation.train_test_split(subset, test_size = 0.2, random_state=1)


dtrain = xgb.DMatrix(train.values[:,:-1], train.values[:,-1])
dtest = xgb.DMatrix(test.values[:,:-1], test.values[:,-1])
param = {'max_depth':10, 'eta':0.3, 'silent':1, "objective": "reg:linear", "booster":"gbtree" }
param['nthread'] = 48
param['eval_metric'] = 'rmse'
evallist  = [(dtest,'eval'), (dtrain,'train')]
num_round = 1000
bst = xgb.train( param, dtrain, num_round, evallist, early_stopping_rounds=10)
# Out:
# (759143, 10)
# [0]	eval-rmse:1.00154	train-rmse:0.996991
# Multiple eval metrics have been passed: 'train-rmse' will be used for early stopping.
#
# Will train until train-rmse hasn't improved in 10 rounds.
# [1]	eval-rmse:0.919175	train-rmse:0.914479
# [2]	eval-rmse:0.881008	train-rmse:0.876026
# [3]	eval-rmse:0.847277	train-rmse:0.841743
# [4]	eval-rmse:0.825367	train-rmse:0.819839
# [5]	eval-rmse:0.799023	train-rmse:0.792744
# [6]	eval-rmse:0.78779	train-rmse:0.781124
# [7]	eval-rmse:0.77625	train-rmse:0.768939
# [8]	eval-rmse:0.764456	train-rmse:0.756493
# [9]	eval-rmse:0.74255	train-rmse:0.733098
# [10]	eval-rmse:0.719245	train-rmse:0.708862
# [11]	eval-rmse:0.712048	train-rmse:0.701328
# [12]	eval-rmse:0.709749	train-rmse:0.698848
# [13]	eval-rmse:0.694367	train-rmse:0.681708
# [14]	eval-rmse:0.689797	train-rmse:0.677063
# [15]	eval-rmse:0.681908	train-rmse:0.668718
# [16]	eval-rmse:0.667904	train-rmse:0.653419
# [17]	eval-rmse:0.665392	train-rmse:0.650674
# [18]	eval-rmse:0.661916	train-rmse:0.646846
# [19]	eval-rmse:0.657175	train-rmse:0.641714
# [20]	eval-rmse:0.645776	train-rmse:0.629319
# [21]	eval-rmse:0.644142	train-rmse:0.627571
# [22]	eval-rmse:0.640858	train-rmse:0.623832
# [23]	eval-rmse:0.633565	train-rmse:0.615763
# [24]	eval-rmse:0.624796	train-rmse:0.605774
# [25]	eval-rmse:0.620771	train-rmse:0.601553
# [26]	eval-rmse:0.614955	train-rmse:0.595354
# [27]	eval-rmse:0.613051	train-rmse:0.593152
# [28]	eval-rmse:0.609664	train-rmse:0.589894
# [29]	eval-rmse:0.605195	train-rmse:0.584826
# [30]	eval-rmse:0.602258	train-rmse:0.581486
# [31]	eval-rmse:0.598322	train-rmse:0.577233
# [32]	eval-rmse:0.590191	train-rmse:0.567835
# [33]	eval-rmse:0.588483	train-rmse:0.565812
# [34]	eval-rmse:0.587186	train-rmse:0.564263
# [35]	eval-rmse:0.580762	train-rmse:0.556933
# [36]	eval-rmse:0.580337	train-rmse:0.556476
# [37]	eval-rmse:0.577971	train-rmse:0.553855
# [790]	eval-rmse:0.273847	train-rmse:0.128479
# [791]	eval-rmse:0.273799	train-rmse:0.128395
# [792]	eval-rmse:0.273658	train-rmse:0.128007
# [793]	eval-rmse:0.273654	train-rmse:0.127983
# [794]	eval-rmse:0.273542	train-rmse:0.127683
# [795]	eval-rmse:0.273516	train-rmse:0.127637
# [796]	eval-rmse:0.27343	train-rmse:0.127562
# [797]	eval-rmse:0.273431	train-rmse:0.127529
# [798]	eval-rmse:0.273398	train-rmse:0.127387
# [799]	eval-rmse:0.273291	train-rmse:0.127256
# [800]	eval-rmse:0.273233	train-rmse:0.12711
# [801]	eval-rmse:0.273201	train-rmse:0.127058
# [802]	eval-rmse:0.273104	train-rmse:0.126902
# [803]	eval-rmse:0.273054	train-rmse:0.126757
# [804]	eval-rmse:0.273053	train-rmse:0.126754
# [805]	eval-rmse:0.27299	train-rmse:0.126528
# [806]	eval-rmse:0.272946	train-rmse:0.126452
# [807]	eval-rmse:0.272851	train-rmse:0.126348
# [808]	eval-rmse:0.272644	train-rmse:0.126089
# [809]	eval-rmse:0.272644	train-rmse:0.126065
# [810]	eval-rmse:0.27261	train-rmse:0.125994
# [811]	eval-rmse:0.272543	train-rmse:0.125901
# [812]	eval-rmse:0.272523	train-rmse:0.125783
# [813]	eval-rmse:0.272458	train-rmse:0.125717
# [814]	eval-rmse:0.272433	train-rmse:0.12559
# [815]	eval-rmse:0.272438	train-rmse:0.125515
# [816]	eval-rmse:0.272438	train-rmse:0.125504
# [817]	eval-rmse:0.27243	train-rmse:0.125468
# [818]	eval-rmse:0.272389	train-rmse:0.1253
# [819]	eval-rmse:0.272326	train-rmse:0.125171
# [820]	eval-rmse:0.272295	train-rmse:0.125108
# [821]	eval-rmse:0.27229	train-rmse:0.125093
# [822]	eval-rmse:0.272242	train-rmse:0.124999
# [823]	eval-rmse:0.272196	train-rmse:0.124768
# [824]	eval-rmse:0.27216	train-rmse:0.124715
# [825]	eval-rmse:0.272077	train-rmse:0.124602
# [826]	eval-rmse:0.272065	train-rmse:0.124521
# [827]	eval-rmse:0.272036	train-rmse:0.124465
# [828]	eval-rmse:0.272002	train-rmse:0.124389
# [829]	eval-rmse:0.271956	train-rmse:0.124295
# [830]	eval-rmse:0.271871	train-rmse:0.124067
# [831]	eval-rmse:0.27184	train-rmse:0.124008
# [832]	eval-rmse:0.271783	train-rmse:0.123803
# [833]	eval-rmse:0.271751	train-rmse:0.123772
# [834]	eval-rmse:0.271709	train-rmse:0.123644
# [835]	eval-rmse:0.271693	train-rmse:0.123546
# [836]	eval-rmse:0.271695	train-rmse:0.123511
# [837]	eval-rmse:0.271511	train-rmse:0.123268
# [838]	eval-rmse:0.271509	train-rmse:0.123221
# [839]	eval-rmse:0.271487	train-rmse:0.123156
# [840]	eval-rmse:0.271468	train-rmse:0.123095
# [841]	eval-rmse:0.271464	train-rmse:0.123083
# [842]	eval-rmse:0.271374	train-rmse:0.12295
# [843]	eval-rmse:0.271356	train-rmse:0.122889
# [952]	eval-rmse:0.267073	train-rmse:0.112117
# [953]	eval-rmse:0.267037	train-rmse:0.112042
# [954]	eval-rmse:0.266985	train-rmse:0.111914
# [955]	eval-rmse:0.266979	train-rmse:0.111791
# [956]	eval-rmse:0.266939	train-rmse:0.111646
# [957]	eval-rmse:0.266938	train-rmse:0.111532
# [958]	eval-rmse:0.266911	train-rmse:0.11143
# [959]	eval-rmse:0.266913	train-rmse:0.111411
# [960]	eval-rmse:0.266892	train-rmse:0.111355
# [961]	eval-rmse:0.266856	train-rmse:0.111221
# [962]	eval-rmse:0.266828	train-rmse:0.111149
# [963]	eval-rmse:0.266773	train-rmse:0.110962
# [964]	eval-rmse:0.266695	train-rmse:0.110834
# [965]	eval-rmse:0.266639	train-rmse:0.110717
# [966]	eval-rmse:0.266617	train-rmse:0.110574
# [967]	eval-rmse:0.26661	train-rmse:0.110561
# [968]	eval-rmse:0.266609	train-rmse:0.110536
# [969]	eval-rmse:0.266601	train-rmse:0.110524
# [970]	eval-rmse:0.2666	train-rmse:0.110516
# [971]	eval-rmse:0.266564	train-rmse:0.11038
# [972]	eval-rmse:0.26649	train-rmse:0.110259
# [973]	eval-rmse:0.266464	train-rmse:0.110202
# [974]	eval-rmse:0.266429	train-rmse:0.110099
# [975]	eval-rmse:0.266368	train-rmse:0.110018
# [976]	eval-rmse:0.266369	train-rmse:0.109941
# [977]	eval-rmse:0.266313	train-rmse:0.10984
# [978]	eval-rmse:0.266208	train-rmse:0.109659
# [979]	eval-rmse:0.266198	train-rmse:0.109587
# [980]	eval-rmse:0.266178	train-rmse:0.109535
# [981]	eval-rmse:0.266105	train-rmse:0.109382
# [982]	eval-rmse:0.266095	train-rmse:0.109357
# [983]	eval-rmse:0.266058	train-rmse:0.109303
# [984]	eval-rmse:0.265968	train-rmse:0.109113
# [985]	eval-rmse:0.265965	train-rmse:0.109099
# [986]	eval-rmse:0.265906	train-rmse:0.109012
# [987]	eval-rmse:0.265903	train-rmse:0.108965
# [988]	eval-rmse:0.2659	train-rmse:0.10896
# [989]	eval-rmse:0.265896	train-rmse:0.108935
# [990]	eval-rmse:0.265865	train-rmse:0.108848
# [991]	eval-rmse:0.265815	train-rmse:0.108593
# [992]	eval-rmse:0.265784	train-rmse:0.108459
# [993]	eval-rmse:0.265771	train-rmse:0.108425
# [994]	eval-rmse:0.265699	train-rmse:0.108207
# [995]	eval-rmse:0.265678	train-rmse:0.108158
# [996]	eval-rmse:0.265609	train-rmse:0.108053
# [997]	eval-rmse:0.26555	train-rmse:0.107982
# [998]	eval-rmse:0.265516	train-rmse:0.107904
# [999]	eval-rmse:0.26551	train-rmse:0.107825

# %%
xgb.plot_importance(bst)

# %%
preds = bst.predict(dtest)
zipped_preds = test
zipped_preds['preds'] = preds

plt.figure()
plt.scatter(zipped_preds['avg_link_slope'], zipped_preds['preds'])
plt.xlabel('avg link slope')
plt.ylabel('predicted link slope')
plt.show()
# Out:
# /home/ec2-user/anaconda3/lib/python3.6/site-packages/ipykernel/__main__.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()
